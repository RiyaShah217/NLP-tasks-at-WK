# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('datasets/NaiveBayes.csv')

# %%
df.head()# first 5 obs
# Out:
#    Age  Salary  Purchased
# 0   19   19000          0
# 1   35   20000          0
# 2   26   43000          0
# 3   27   57000          0
# 4   19   76000          0

# %%
df.tail()#last 5 obs
# Out:
#      Age  Salary  Purchased
# 395   46   41000          1
# 396   51   23000          1
# 397   50   20000          1
# 398   36   33000          0
# 399   49   36000          1

# %%
df.shape #400 rows and 3 columns
# Out:
# (400, 3)

# %%
df.columns
# Out:
# Index(['Age', 'Salary', 'Purchased'], dtype='object')

# %%
df.dtypes # displays datatypes
# Out:
# Age          int64
# Salary       int64
# Purchased    int64
# dtype: object

# %%
df.count() #counts the number of non-empty values
# Out:
# Age          400
# Salary       400
# Purchased    400
# dtype: int64

# %%
df.nunique()
# Out:
# Age           43
# Salary       117
# Purchased      2
# dtype: int64

# %%
df['Age'].unique()
# Out:
# array([19, 35, 26, 27, 32, 25, 20, 18, 29, 47, 45, 46, 48, 49, 31, 21, 28,
#        33, 30, 23, 24, 22, 59, 34, 39, 38, 37, 42, 40, 36, 41, 58, 55, 52,
#        60, 56, 53, 50, 51, 57, 44, 43, 54], dtype=int64)

# %%
df.describe() #gives statistical info of data
# Out:
#               Age         Salary   Purchased
# count  400.000000     400.000000  400.000000
# mean    37.655000   69742.500000    0.357500
# std     10.482877   34096.960282    0.479864
# min     18.000000   15000.000000    0.000000
# 25%     29.750000   43000.000000    0.000000
# 50%     37.000000   70000.000000    0.000000
# 75%     46.000000   88000.000000    1.000000
# max     60.000000  150000.000000    1.000000

# %%
df.describe(include='all')
# Out:
#               Age         Salary   Purchased
# count  400.000000     400.000000  400.000000
# mean    37.655000   69742.500000    0.357500
# std     10.482877   34096.960282    0.479864
# min     18.000000   15000.000000    0.000000
# 25%     29.750000   43000.000000    0.000000
# 50%     37.000000   70000.000000    0.000000
# 75%     46.000000   88000.000000    1.000000
# max     60.000000  150000.000000    1.000000

# %%
df.info() #complete summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        400 non-null    int64
#  1   Salary     400 non-null    int64
#  2   Purchased  400 non-null    int64
# dtypes: int64(3)
# memory usage: 9.5 KB

# %%
df.Age=pd.to_numeric(df.Age,errors='coerce') #finding missing values
df.isnull().sum()
# Out:
# Age          0
# Salary       0
# Purchased    0
# dtype: int64

# %%
#We do not have any missing values in the given dataset

# %%
corelation=df.corr()

# %%
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
sns.relplot(x='Age',y='Salary',hue='Purchased',data=df)

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\riya.shah\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Age'],bins=5)
# Out:
# C:\Users\riya.shah\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
df.Salary.value_counts(normalize=True)

#plot the bar graph of percentage salary categories
df.Salary.value_counts(normalize=True).plot.barh()
plt.show()

# %%
df.Age.value_counts(normalize=True)

#plot the bar graph of percentage salary categories
df.Age.value_counts(normalize=True).plot.pie()
plt.show()

# %%
plt.scatter(df.Salary,df.Age)
plt.show()

#plot the scatter plot of balance and age variable in data
df.plot.scatter(x="age",y="purchased")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
